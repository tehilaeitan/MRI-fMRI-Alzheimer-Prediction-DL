# %% [markdown]
# ### Importing Packages

# %%
import os
import scipy
from scipy.ndimage import zoom
import nibabel as nib
from nilearn import plotting
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from matplotlib import image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers,models
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, GlobalAveragePooling2D,Dropout
from tensorflow.keras.losses import CategoricalCrossentropy,MeanSquaredError
from tensorflow.keras.losses import SparseCategoricalCrossentropy as SparseCategoricalCrossentropyV1
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.metrics import Accuracy,CategoricalAccuracy,SparseCategoricalAccuracy
from tensorflow.keras.models import Model,Sequential
import tensorflow.keras.backend as K
from sklearn.utils import class_weight
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.callbacks import History, EarlyStopping
import seaborn as sns
# Out:
# WARNING:tensorflow:From C:\Users\Cognition\anaconda3\envs\rantehila\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
folder_path = 'D:\Tehila_Ran_Data\ADNI2PRECN\ADNI'
CN_fmri = []
labels_CN = []
cnt=0
for root, dirs, files in os.walk(folder_path):
    for filename in files:
        if filename.endswith('.nii') and cnt<1000:  
            image_path = os.path.join(root, filename)
            img = nib.load(image_path)
            img_data = img.get_fdata()

            
            CN_fmri.append(img_data)
            labels_CN.append(0)
            cnt+=1

# %%
folder_path = 'D:\Tehila_Ran_Data\ADNI2PREMCI\ADNI'
MCI_fmri = []
labels_MCI = []
for root, dirs, files in os.walk(folder_path):
    for filename in files:
        if filename.endswith('.nii'):  
            image_path = os.path.join(root, filename)
            img = nib.load(image_path)
            img_data = img.get_fdata()
            

            MCI_fmri.append(img_data)
            labels_MCI.append(1)

# %%
folder_path = 'D:\Tehila_Ran_Data\ADNI2PREAD\ADNI'
AD_fmri = []
labels_AD = []
cnt=0
for root, dirs, files in os.walk(folder_path):
    for filename in files:
        if filename.endswith('.nii') and cnt<1000:  
            image_path = os.path.join(root, filename)
            img = nib.load(image_path)
            img_data = img.get_fdata()
            
            
            AD_fmri.append(img_data)
            labels_AD.append(2)
            cnt+=1

# %% [markdown]
# ### Preprocessing for fitting the 3D CNN model

# %%
for i, arr in enumerate(CN_fmri[:200]):
    print(f"CN_fmri[{i}] shape:", np.array(arr).shape)
# Out:
# CN_fmri[0] shape: (170, 256, 256)
# CN_fmri[1] shape: (170, 256, 256)
# CN_fmri[2] shape: (170, 256, 256)
# CN_fmri[3] shape: (170, 256, 256)
# CN_fmri[4] shape: (170, 256, 256)
# CN_fmri[5] shape: (170, 256, 256)
# CN_fmri[6] shape: (170, 256, 256)
# CN_fmri[7] shape: (170, 256, 256)
# CN_fmri[8] shape: (170, 256, 256)
# CN_fmri[9] shape: (170, 256, 256)
# CN_fmri[10] shape: (170, 256, 256)
# CN_fmri[11] shape: (170, 256, 256)
# CN_fmri[12] shape: (170, 256, 256)
# CN_fmri[13] shape: (170, 256, 256)
# CN_fmri[14] shape: (170, 256, 256)
# CN_fmri[15] shape: (170, 256, 256)
# CN_fmri[16] shape: (170, 256, 256)
# CN_fmri[17] shape: (170, 256, 256)
# CN_fmri[18] shape: (170, 256, 256)
# CN_fmri[19] shape: (170, 256, 256)
# CN_fmri[20] shape: (170, 256, 256)
# CN_fmri[21] shape: (170, 256, 256)
# CN_fmri[22] shape: (170, 256, 256)
# CN_fmri[23] shape: (170, 256, 256)
# CN_fmri[24] shape: (170, 256, 256)
# CN_fmri[25] shape: (170, 256, 256)
# CN_fmri[26] shape: (170, 256, 256)
# CN_fmri[27] shape: (170, 256, 256)
# CN_fmri[28] shape: (170, 256, 256)
# CN_fmri[29] shape: (170, 256, 256)
# CN_fmri[30] shape: (170, 256, 256)
# CN_fmri[31] shape: (170, 256, 256)
# CN_fmri[32] shape: (170, 256, 256)
# CN_fmri[33] shape: (170, 256, 256)
# CN_fmri[34] shape: (170, 256, 256)
# CN_fmri[35] shape: (170, 256, 256)
# CN_fmri[36] shape: (170, 256, 256)
# CN_fmri[37] shape: (170, 256, 256)
# CN_fmri[38] shape: (170, 256, 256)
# CN_fmri[39] shape: (170, 256, 256)
# CN_fmri[40] shape: (170, 256, 256)
# CN_fmri[41] shape: (170, 256, 256)
# CN_fmri[42] shape: (170, 256, 256)
# CN_fmri[43] shape: (170, 256, 256)
# CN_fmri[44] shape: (170, 256, 256)
# CN_fmri[45] shape: (170, 256, 256)
# CN_fmri[46] shape: (197, 233, 189)
# CN_fmri[47] shape: (197, 233, 189)
# CN_fmri[48] shape: (170, 256, 256)
# CN_fmri[49] shape: (170, 256, 256)
# CN_fmri[50] shape: (170, 256, 256)
# CN_fmri[51] shape: (170, 256, 256)
# CN_fmri[52] shape: (170, 256, 256)
# CN_fmri[53] shape: (170, 256, 256)
# CN_fmri[54] shape: (170, 256, 256)
# CN_fmri[55] shape: (170, 256, 256)
# CN_fmri[56] shape: (170, 256, 256)
# CN_fmri[57] shape: (170, 256, 256)
# CN_fmri[58] shape: (170, 256, 256)
# CN_fmri[59] shape: (170, 256, 256)
# CN_fmri[60] shape: (170, 256, 256)
# CN_fmri[61] shape: (170, 256, 256)
# CN_fmri[62] shape: (170, 256, 256)
# CN_fmri[63] shape: (170, 256, 256)
# CN_fmri[64] shape: (170, 256, 256)
# CN_fmri[65] shape: (170, 256, 256)
# CN_fmri[66] shape: (170, 256, 256)
# CN_fmri[67] shape: (170, 256, 256)
# CN_fmri[68] shape: (170, 256, 256)
# CN_fmri[69] shape: (170, 256, 256)
# CN_fmri[70] shape: (170, 256, 256)
# CN_fmri[71] shape: (170, 256, 256)
# CN_fmri[72] shape: (170, 256, 256)
# CN_fmri[73] shape: (170, 256, 256)
# CN_fmri[74] shape: (170, 256, 256)
# CN_fmri[75] shape: (170, 256, 256)
# CN_fmri[76] shape: (170, 256, 256)
# CN_fmri[77] shape: (170, 256, 256)
# CN_fmri[78] shape: (170, 256, 256)
# CN_fmri[79] shape: (170, 256, 256)
# CN_fmri[80] shape: (170, 256, 256)
# CN_fmri[81] shape: (170, 256, 256)
# CN_fmri[82] shape: (170, 256, 256)
# CN_fmri[83] shape: (170, 256, 256)
# CN_fmri[84] shape: (170, 256, 256)
# CN_fmri[85] shape: (170, 256, 256)
# CN_fmri[86] shape: (160, 192, 192)
# CN_fmri[87] shape: (160, 192, 192)
# CN_fmri[88] shape: (160, 192, 192)
# CN_fmri[89] shape: (160, 192, 192)
# CN_fmri[90] shape: (160, 192, 192)
# CN_fmri[91] shape: (160, 192, 192)
# CN_fmri[92] shape: (160, 192, 192)
# CN_fmri[93] shape: (160, 192, 192)
# CN_fmri[94] shape: (160, 192, 192)
# CN_fmri[95] shape: (196, 256, 256)
# CN_fmri[96] shape: (196, 256, 256)
# CN_fmri[97] shape: (196, 256, 256)
# CN_fmri[98] shape: (196, 256, 256)
# CN_fmri[99] shape: (110, 110, 110)
# CN_fmri[100] shape: (110, 110, 110)
# CN_fmri[101] shape: (196, 256, 256)
# CN_fmri[102] shape: (196, 256, 256)
# CN_fmri[103] shape: (196, 256, 256)
# CN_fmri[104] shape: (196, 256, 256)
# CN_fmri[105] shape: (196, 256, 256)
# CN_fmri[106] shape: (196, 256, 256)
# CN_fmri[107] shape: (196, 256, 256)
# CN_fmri[108] shape: (196, 256, 256)
# CN_fmri[109] shape: (110, 110, 110)
# CN_fmri[110] shape: (110, 110, 110)
# CN_fmri[111] shape: (110, 110, 110)
# CN_fmri[112] shape: (196, 256, 256)
# CN_fmri[113] shape: (196, 256, 256)
# CN_fmri[114] shape: (196, 256, 256)
# CN_fmri[115] shape: (196, 256, 256)
# CN_fmri[116] shape: (196, 256, 256)
# CN_fmri[117] shape: (196, 256, 256)
# CN_fmri[118] shape: (196, 256, 256)
# CN_fmri[119] shape: (196, 256, 256)
# CN_fmri[120] shape: (196, 256, 256)
# CN_fmri[121] shape: (196, 256, 256)
# CN_fmri[122] shape: (110, 110, 110)
# CN_fmri[123] shape: (110, 110, 110)
# CN_fmri[124] shape: (110, 110, 110)
# CN_fmri[125] shape: (110, 110, 110)
# CN_fmri[126] shape: (110, 110, 110)
# CN_fmri[127] shape: (196, 256, 256)
# CN_fmri[128] shape: (196, 256, 256)
# CN_fmri[129] shape: (196, 256, 256)
# CN_fmri[130] shape: (196, 256, 256)
# CN_fmri[131] shape: (196, 256, 256)
# CN_fmri[132] shape: (196, 256, 256)
# CN_fmri[133] shape: (196, 256, 256)
# CN_fmri[134] shape: (196, 256, 256)
# CN_fmri[135] shape: (196, 256, 256)
# CN_fmri[136] shape: (196, 256, 256)
# CN_fmri[137] shape: (196, 256, 256)
# CN_fmri[138] shape: (196, 256, 256)
# CN_fmri[139] shape: (110, 110, 110)
# CN_fmri[140] shape: (110, 110, 110)
# CN_fmri[141] shape: (110, 110, 110)
# CN_fmri[142] shape: (110, 110, 110)
# CN_fmri[143] shape: (110, 110, 110)
# CN_fmri[144] shape: (196, 256, 256)
# CN_fmri[145] shape: (196, 256, 256)
# CN_fmri[146] shape: (196, 256, 256)
# CN_fmri[147] shape: (196, 256, 256)
# CN_fmri[148] shape: (196, 256, 256)
# CN_fmri[149] shape: (196, 256, 256)
# CN_fmri[150] shape: (196, 256, 256)
# CN_fmri[151] shape: (196, 256, 256)
# CN_fmri[152] shape: (110, 110, 110)
# CN_fmri[153] shape: (110, 110, 110)
# CN_fmri[154] shape: (110, 110, 110)
# CN_fmri[155] shape: (110, 110, 110)
# CN_fmri[156] shape: (196, 256, 256)
# CN_fmri[157] shape: (196, 256, 256)
# CN_fmri[158] shape: (196, 256, 256)
# CN_fmri[159] shape: (196, 256, 256)
# CN_fmri[160] shape: (196, 256, 256)
# CN_fmri[161] shape: (196, 256, 256)
# CN_fmri[162] shape: (110, 110, 110)
# CN_fmri[163] shape: (110, 110, 110)
# CN_fmri[164] shape: (110, 110, 110)
# CN_fmri[165] shape: (196, 256, 256)
# CN_fmri[166] shape: (196, 256, 256)
# CN_fmri[167] shape: (196, 256, 256)
# CN_fmri[168] shape: (196, 256, 256)
# CN_fmri[169] shape: (196, 256, 256)
# CN_fmri[170] shape: (196, 256, 256)
# CN_fmri[171] shape: (110, 110, 110)
# CN_fmri[172] shape: (110, 110, 110)
# CN_fmri[173] shape: (110, 110, 110)
# CN_fmri[174] shape: (196, 256, 256)
# CN_fmri[175] shape: (196, 256, 256)
# CN_fmri[176] shape: (110, 110, 110)
# CN_fmri[177] shape: (196, 256, 256)
# CN_fmri[178] shape: (196, 256, 256)
# CN_fmri[179] shape: (110, 110, 110)
# CN_fmri[180] shape: (196, 256, 256)
# CN_fmri[181] shape: (196, 256, 256)
# CN_fmri[182] shape: (196, 256, 256)
# CN_fmri[183] shape: (196, 256, 256)
# CN_fmri[184] shape: (196, 256, 256)
# CN_fmri[185] shape: (196, 256, 256)
# CN_fmri[186] shape: (196, 256, 256)
# CN_fmri[187] shape: (196, 256, 256)
# CN_fmri[188] shape: (110, 110, 110)
# CN_fmri[189] shape: (110, 110, 110)
# CN_fmri[190] shape: (110, 110, 110)
# CN_fmri[191] shape: (110, 110, 110)
# CN_fmri[192] shape: (196, 256, 256)
# CN_fmri[193] shape: (196, 256, 256)
# CN_fmri[194] shape: (196, 256, 256)
# CN_fmri[195] shape: (196, 256, 256)
# CN_fmri[196] shape: (196, 256, 256)
# CN_fmri[197] shape: (196, 256, 256)
# CN_fmri[198] shape: (196, 256, 256)
# CN_fmri[199] shape: (196, 256, 256)

# %% [markdown]
# ### Reshaping

# %%
target_shape = (90,108,108)  # Specify your desired shape here

# Initialize lists to store resized images
resized_CN_fmri = []
resized_MCI_fmri = []
resized_AD_fmri = []

# Resize images in CN_fmri
for img in CN_fmri:
    resized_img = zoom(img, target_shape / np.array(img.shape), order=1)
    resized_CN_fmri.append(resized_img)

CN_fmri = 0
# Resize images in MCI_fmri
for img in MCI_fmri:
    resized_img = zoom(img, target_shape / np.array(img.shape), order=1)
    resized_MCI_fmri.append(resized_img)

MCI_fmri = 0
# Resize images in AD_fmri
for img in AD_fmri:
    resized_img = zoom(img, target_shape / np.array(img.shape), order=1)
    resized_AD_fmri.append(resized_img)

AD_fmri = 0

# %%
features = np.concatenate((np.array(resized_CN_fmri),np.array(resized_MCI_fmri),np.array(resized_AD_fmri)), axis=0)

# %%
labels = np.concatenate((labels_CN,labels_MCI,labels_AD), axis=0)

# %%
x_size, y_size, z_size= features[200].shape
features[200].shape
# Out:
# (90, 108, 108)

# %%
x_train, x_te, y_train, y_te = train_test_split(features,labels,test_size=0.3,stratify=labels)
x_val, x_test, y_val, y_test = train_test_split(x_te,y_te,test_size=0.5,stratify=y_te)

# %% [markdown]
# ## The model - 3D convolutional neural network

# %% [markdown]
# ### No dropout

# %%
model = models.Sequential()

# Convolutional layers
model.add(Conv3D(64, kernel_size=(3, 3, 3), activation='relu', input_shape=(x_size, y_size, z_size,1)))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Conv3D(32, kernel_size=(2, 2, 2), activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))


model.add(Flatten())

# Dense layers
model.add(Dense(128, activation='relu'))
model.add(Dense(3, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 88, 106, 106, 64   1792
#                              )
#
#  max_pooling3d_4 (MaxPoolin  (None, 44, 53, 53, 64)    0
#  g3D)
#
#  conv3d_5 (Conv3D)           (None, 43, 52, 52, 32)    16416
#
#  max_pooling3d_5 (MaxPoolin  (None, 21, 26, 26, 32)    0
#  g3D)
#
#  flatten_2 (Flatten)         (None, 454272)            0
#
#  dense_4 (Dense)             (None, 128)               58146944
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 58165539 (221.88 MB)
# Trainable params: 58165539 (221.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_callback = History()
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True)
history = model.fit(x_train, y_train, epochs=200, validation_data=(x_val, y_val),callbacks=[history_callback, early_stopping])
train_loss_values = history.history['loss']
train_acc_values = history.history['accuracy']
val_loss_values = history.history['val_loss']
val_acc_values = history.history['val_accuracy']


# Evaluate the model on the test set
val_loss, val_accuracy =  model.evaluate(x_val, y_val)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)


test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/200
# 58/58 [==============================] - 597s 10s/step - loss: 1459.9156 - accuracy: 0.4340 - val_loss: 0.9678 - val_accuracy: 0.4731
# Epoch 2/200
# 58/58 [==============================] - 589s 10s/step - loss: 0.9097 - accuracy: 0.5380 - val_loss: 0.9267 - val_accuracy: 0.4808
# Epoch 3/200
# 58/58 [==============================] - 583s 10s/step - loss: 0.7445 - accuracy: 0.6645 - val_loss: 0.9267 - val_accuracy: 0.5371
# Epoch 4/200
# 58/58 [==============================] - 584s 10s/step - loss: 0.5868 - accuracy: 0.7701 - val_loss: 1.0190 - val_accuracy: 0.6138
# Epoch 5/200
# 58/58 [==============================] - 590s 10s/step - loss: 0.4162 - accuracy: 0.8506 - val_loss: 1.0453 - val_accuracy: 0.6240
# Epoch 6/200
# 58/58 [==============================] - 585s 10s/step - loss: 0.2727 - accuracy: 0.9130 - val_loss: 1.1990 - val_accuracy: 0.6598
# Epoch 7/200
# 58/58 [==============================] - 583s 10s/step - loss: 0.1726 - accuracy: 0.9502 - val_loss: 1.4373 - val_accuracy: 0.6675
# Epoch 8/200
# 58/58 [==============================] - 585s 10s/step - loss: 0.1929 - accuracy: 0.9562 - val_loss: 1.4010 - val_accuracy: 0.6471
# Epoch 9/200
# 58/58 [==============================] - 4091s 72s/step - loss: 0.1099 - accuracy: 0.9726 - val_loss: 2.2076 - val_accuracy: 0.6752
# Epoch 10/200
# 58/58 [==============================] - 588s 10s/step - loss: 0.0791 - accuracy: 0.9841 - val_loss: 2.4315 - val_accuracy: 0.6598
# Epoch 11/200
# 58/58 [==============================] - 591s 10s/step - loss: 0.0614 - accuracy: 0.9858 - val_loss: 2.5315 - val_accuracy: 0.6624
# Epoch 12/200
# 58/58 [==============================] - 589s 10s/step - loss: 0.0564 - accuracy: 0.9885 - val_loss: 2.8349 - val_accuracy: 0.6624
# Epoch 13/200
# 58/58 [==============================] - 588s 10s/step - loss: 0.0323 - accuracy: 0.9940 - val_loss: 2.8307 - val_accuracy: 0.6701
# Epoch 14/200
# 58/58 [==============================] - 586s 10s/step - loss: 0.0164 - accuracy: 0.9978 - val_loss: 3.8522 - val_accuracy: 0.6675
# Epoch 15/200
# 58/58 [==============================] - 585s 10s/step - loss: 0.0391 - accuracy: 0.9880 - val_loss: 3.4742 - val_accuracy: 0.6803
# Epoch 16/200
# 58/58 [==============================] - 585s 10s/step - loss: 0.0528 - accuracy: 0.9929 - val_loss: 2.8102 - val_accuracy: 0.6701
# Epoch 17/200
# 58/58 [==============================] - 592s 10s/step - loss: 0.0317 - accuracy: 0.9929 - val_loss: 3.7624 - val_accuracy: 0.7059
# Epoch 18/200
# 58/58 [==============================] - 591s 10s/step - loss: 0.1696 - accuracy: 0.9557 - val_loss: 2.4182 - val_accuracy: 0.6496
# Epoch 19/200
# 58/58 [==============================] - 585s 10s/step - loss: 0.0847 - accuracy: 0.9797 - val_loss: 2.3463 - val_accuracy: 0.7110
# Epoch 20/200
# 58/58 [==============================] - 585s 10s/step - loss: 0.0509 - accuracy: 0.9912 - val_loss: 2.9883 - val_accuracy: 0.6982
# Epoch 21/200
# 58/58 [==============================] - 586s 10s/step - loss: 0.0240 - accuracy: 0.9967 - val_loss: 2.7303 - val_accuracy: 0.7187
# Epoch 22/200
# 58/58 [==============================] - 584s 10s/step - loss: 0.0074 - accuracy: 0.9995 - val_loss: 3.6565 - val_accuracy: 0.7238
# Epoch 23/200
# 58/58 [==============================] - 587s 10s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.9246 - val_accuracy: 0.7263
# Epoch 24/200
# 58/58 [==============================] - 2409s 42s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 4.0990 - val_accuracy: 0.7315
# Epoch 25/200
# 58/58 [==============================] - 587s 10s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 4.2643 - val_accuracy: 0.7417
# Epoch 26/200
# 58/58 [==============================] - 586s 10s/step - loss: 8.9223e-04 - accuracy: 1.0000 - val_loss: 4.3893 - val_accuracy: 0.7545
# Epoch 27/200
# 58/58 [==============================] - 586s 10s/step - loss: 6.0109e-04 - accuracy: 1.0000 - val_loss: 4.4167 - val_accuracy: 0.7545
# Epoch 28/200
# 58/58 [==============================] - 585s 10s/step - loss: 4.0175e-04 - accuracy: 1.0000 - val_loss: 4.4797 - val_accuracy: 0.7570
# Epoch 29/200
# 58/58 [==============================] - 585s 10s/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 3.4278 - val_accuracy: 0.7212
# Epoch 30/200
# 58/58 [==============================] - 2217s 39s/step - loss: 0.1032 - accuracy: 0.9787 - val_loss: 3.8326 - val_accuracy: 0.7187
# Epoch 31/200
# 58/58 [==============================] - 586s 10s/step - loss: 0.0488 - accuracy: 0.9912 - val_loss: 3.7211 - val_accuracy: 0.6624
# Epoch 32/200
# 58/58 [==============================] - 583s 10s/step - loss: 0.1151 - accuracy: 0.9781 - val_loss: 2.8141 - val_accuracy: 0.6905
# Epoch 33/200
# 58/58 [==============================] - 588s 10s/step - loss: 0.0512 - accuracy: 0.9912 - val_loss: 3.4856 - val_accuracy: 0.6905
# Epoch 34/200
# 58/58 [==============================] - 583s 10s/step - loss: 0.0156 - accuracy: 0.9973 - val_loss: 3.8493 - val_accuracy: 0.6803
# Epoch 35/200
# 58/58 [==============================] - 586s 10s/step - loss: 0.0069 - accuracy: 0.9989 - val_loss: 3.4388 - val_accuracy: 0.6598
# Epoch 36/200
# 58/58 [==============================] - 1726s 30s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 4.0621 - val_accuracy: 0.6880
# Epoch 37/200
# 58/58 [==============================] - 588s 10s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 4.3502 - val_accuracy: 0.6931
# Epoch 38/200
# 58/58 [==============================] - 583s 10s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 4.4756 - val_accuracy: 0.6931
# Epoch 39/200
# 58/58 [==============================] - 351s 6s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 4.6216 - val_accuracy: 0.6931
# Epoch 40/200
# 58/58 [==============================] - 318s 5s/step - loss: 9.7562e-04 - accuracy: 1.0000 - val_loss: 4.7865 - val_accuracy: 0.6931
# Epoch 41/200
# 58/58 [==============================] - 320s 6s/step - loss: 8.2416e-04 - accuracy: 1.0000 - val_loss: 4.9106 - val_accuracy: 0.7008
# Epoch 42/200
# 58/58 [==============================] - 317s 5s/step - loss: 6.9410e-04 - accuracy: 1.0000 - val_loss: 5.0112 - val_accuracy: 0.6957
# Epoch 43/200
# 58/58 [==============================] - 319s 6s/step - loss: 5.9432e-04 - accuracy: 1.0000 - val_loss: 5.1320 - val_accuracy: 0.6931
# Epoch 44/200
# 58/58 [==============================] - 317s 5s/step - loss: 5.1389e-04 - accuracy: 1.0000 - val_loss: 5.2194 - val_accuracy: 0.6931
# Epoch 45/200
# 58/58 [==============================] - 318s 5s/step - loss: 4.5347e-04 - accuracy: 1.0000 - val_loss: 5.2985 - val_accuracy: 0.6905
# Epoch 46/200
# 58/58 [==============================] - 3246s 57s/step - loss: 4.0262e-04 - accuracy: 1.0000 - val_loss: 5.3912 - val_accuracy: 0.6905
# Epoch 47/200
# 58/58 [==============================] - 324s 6s/step - loss: 3.5796e-04 - accuracy: 1.0000 - val_loss: 5.4765 - val_accuracy: 0.6880
# Epoch 48/200
# 58/58 [==============================] - 323s 6s/step - loss: 3.2189e-04 - accuracy: 1.0000 - val_loss: 5.5469 - val_accuracy: 0.6905
# Epoch 49/200
# 58/58 [==============================] - 323s 6s/step - loss: 2.9101e-04 - accuracy: 1.0000 - val_loss: 5.6142 - val_accuracy: 0.6880
# Epoch 50/200
# 58/58 [==============================] - 323s 6s/step - loss: 2.6214e-04 - accuracy: 1.0000 - val_loss: 5.6976 - val_accuracy: 0.6880
# Epoch 51/200
# 58/58 [==============================] - 323s 6s/step - loss: 2.3843e-04 - accuracy: 1.0000 - val_loss: 5.7721 - val_accuracy: 0.6880
# Epoch 52/200
# 58/58 [==============================] - 322s 6s/step - loss: 2.1770e-04 - accuracy: 1.0000 - val_loss: 5.8363 - val_accuracy: 0.6905
# Epoch 53/200
# 58/58 [==============================] - 323s 6s/step - loss: 1.9866e-04 - accuracy: 1.0000 - val_loss: 5.9102 - val_accuracy: 0.6931
# Epoch 54/200
# 58/58 [==============================] - 322s 6s/step - loss: 1.8181e-04 - accuracy: 1.0000 - val_loss: 5.9732 - val_accuracy: 0.6982
# Epoch 55/200
# 58/58 [==============================] - 321s 6s/step - loss: 1.6705e-04 - accuracy: 1.0000 - val_loss: 6.0414 - val_accuracy: 0.6931
# Epoch 56/200
# 58/58 [==============================] - 323s 6s/step - loss: 1.5521e-04 - accuracy: 1.0000 - val_loss: 6.1225 - val_accuracy: 0.6982
# Epoch 57/200
# 58/58 [==============================] - 1613s 28s/step - loss: 1.4280e-04 - accuracy: 1.0000 - val_loss: 6.1800 - val_accuracy: 0.6982
# Epoch 58/200
# 58/58 [==============================] - 319s 6s/step - loss: 1.3347e-04 - accuracy: 1.0000 - val_loss: 6.2569 - val_accuracy: 0.6982
# 13/13 [==============================] - 16s 1s/step - loss: 4.4797 - accuracy: 0.7570
# Validation Loss: 4.479740619659424
# Validation Accuracy: 0.7570332288742065
# 13/13 [==============================] - 16s 1s/step - loss: 3.9027 - accuracy: 0.7423
# Test Loss: 3.9027163982391357
# Test Accuracy: 0.7423469424247742

# %%
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=1)
df = pd.DataFrame(data = confusion_matrix(y_test, predictions),
  columns = ['CN','MCI', 'AD'],
  index = ['CN','MCI', 'AD'])
sns.heatmap(df, cmap="Greens", annot=True, fmt='.0f')
# Out:
# 13/13 [==============================] - 16s 1s/step
# <Axes: >

# %%
mat = confusion_matrix(y_test, predictions)
df =pd.DataFrame((mat/mat.sum(axis = 1,keepdims = True)).round(2), columns = ['CN','MCI', 'AD'],index = ['CN','MCI', 'AD'])
sns.heatmap(df, cmap="Greens", annot=True)
# Out:
# <Axes: >

# %%
predictions = model.predict(x_val)
predictions = np.argmax(predictions, axis=1)
df = pd.DataFrame(data = confusion_matrix(y_val, predictions),
  columns = ['CN','MCI', 'AD'],
  index = ['CN','MCI', 'AD'])
sns.heatmap(df, cmap="Greens", annot=True, fmt='.0f')
# Out:
# 13/13 [==============================] - 16s 1s/step
# <Axes: >

# %%
mat = confusion_matrix(y_val, predictions)
df =pd.DataFrame((mat/mat.sum(axis = 1,keepdims = True)).round(2), columns = ['CN','MCI', 'AD'],index = ['CN','MCI', 'AD'])
sns.heatmap(df, cmap="Greens", annot=True)
# Out:
# <Axes: >

# %%
epochs_applied = early_stopping.stopped_epoch + 1
if epochs_applied<10:
    epochs_applied=200

# %%
lenx = [i+1 for i in range(epochs_applied)]
plt.plot(lenx, train_acc_values, label = "train acc")
plt.plot(lenx, val_acc_values, label = "val acc")
#plt.plot(lenx, test_acc_values, label = "test acc")
plt.legend()
plt.show()

# %%
lenx = [i+1 for i in range(epochs_applied-1)]
plt.plot(lenx, train_loss_values[1:],label = "train loss")
plt.plot(lenx, val_loss_values[1:], label = "val loss")
#plt.plot(lenx, test_loss_values, label = "test loss")
plt.legend()
plt.show()

# %%
K.clear_session()

# %% [markdown]
# ### Dropout

# %%
model = models.Sequential()

# Convolutional layers
model.add(Conv3D(64, kernel_size=(3, 3, 3), activation='relu', input_shape=(x_size, y_size, z_size,1)))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.3))
model.add(Conv3D(32, kernel_size=(3, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

model.add(Flatten())
model.add(Dropout(0.3))

# Dense layers
model.add(Dense(128, activation='relu'))
model.add(Dense(3, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Confusion matrixes and results

# %%
history_callback = History()
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True)
history = model.fit(x_train, y_train, epochs=200, validation_data=(x_val, y_val),callbacks=[history_callback, early_stopping])
train_loss_values = history.history['loss']
train_acc_values = history.history['accuracy']
val_loss_values = history.history['val_loss']
val_acc_values = history.history['val_accuracy']


# Evaluate the model on the test set
val_loss, val_accuracy =  model.evaluate(x_val, y_val)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_accuracy)


test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/200
# 58/58 [==============================] - 435s 8s/step - loss: 1635.1331 - accuracy: 0.4012 - val_loss: 1.0767 - val_accuracy: 0.3248
# Epoch 2/200
# 58/58 [==============================] - 426s 7s/step - loss: 1.1313 - accuracy: 0.3946 - val_loss: 1.0818 - val_accuracy: 0.3453
# Epoch 3/200
# 58/58 [==============================] - 425s 7s/step - loss: 1.0814 - accuracy: 0.3870 - val_loss: 1.0811 - val_accuracy: 0.3683
# Epoch 4/200
# 58/58 [==============================] - 429s 7s/step - loss: 1.0413 - accuracy: 0.4072 - val_loss: 1.0596 - val_accuracy: 0.3734
# Epoch 5/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.9967 - accuracy: 0.4132 - val_loss: 1.0452 - val_accuracy: 0.3964
# Epoch 6/200
# 58/58 [==============================] - 431s 7s/step - loss: 1.0011 - accuracy: 0.4351 - val_loss: 1.0430 - val_accuracy: 0.4501
# Epoch 7/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.9680 - accuracy: 0.4532 - val_loss: 1.0282 - val_accuracy: 0.4399
# Epoch 8/200
# 58/58 [==============================] - 427s 7s/step - loss: 0.9453 - accuracy: 0.4685 - val_loss: 1.0127 - val_accuracy: 0.4604
# Epoch 9/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.9186 - accuracy: 0.4817 - val_loss: 0.9907 - val_accuracy: 0.4731
# Epoch 10/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.8881 - accuracy: 0.5183 - val_loss: 0.9754 - val_accuracy: 0.5013
# Epoch 11/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.8546 - accuracy: 0.5386 - val_loss: 0.9757 - val_accuracy: 0.5115
# Epoch 12/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.8313 - accuracy: 0.5649 - val_loss: 0.9409 - val_accuracy: 0.5217
# Epoch 13/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.8125 - accuracy: 0.5813 - val_loss: 0.9616 - val_accuracy: 0.5141
# Epoch 14/200
# 58/58 [==============================] - 427s 7s/step - loss: 0.7879 - accuracy: 0.5857 - val_loss: 0.9624 - val_accuracy: 0.4987
# Epoch 15/200
# 58/58 [==============================] - 612s 11s/step - loss: 0.7899 - accuracy: 0.5873 - val_loss: 0.9848 - val_accuracy: 0.5013
# Epoch 16/200
# 58/58 [==============================] - 429s 7s/step - loss: 0.7734 - accuracy: 0.5961 - val_loss: 1.0158 - val_accuracy: 0.4987
# Epoch 17/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.7538 - accuracy: 0.6190 - val_loss: 0.9713 - val_accuracy: 0.5217
# Epoch 18/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.7150 - accuracy: 0.6404 - val_loss: 0.9292 - val_accuracy: 0.5575
# Epoch 19/200
# 58/58 [==============================] - 427s 7s/step - loss: 0.7214 - accuracy: 0.6289 - val_loss: 0.9638 - val_accuracy: 0.5345
# Epoch 20/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.6924 - accuracy: 0.6404 - val_loss: 0.9397 - val_accuracy: 0.5320
# Epoch 21/200
# 58/58 [==============================] - 432s 7s/step - loss: 0.6796 - accuracy: 0.6508 - val_loss: 0.9255 - val_accuracy: 0.5627
# Epoch 22/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.6797 - accuracy: 0.6541 - val_loss: 0.9969 - val_accuracy: 0.5729
# Epoch 23/200
# 58/58 [==============================] - 1089s 19s/step - loss: 0.6377 - accuracy: 0.6842 - val_loss: 1.0759 - val_accuracy: 0.5780
# Epoch 24/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.6690 - accuracy: 0.6689 - val_loss: 1.0122 - val_accuracy: 0.5601
# Epoch 25/200
# 58/58 [==============================] - 427s 7s/step - loss: 0.6638 - accuracy: 0.6667 - val_loss: 1.0436 - val_accuracy: 0.5959
# Epoch 26/200
# 58/58 [==============================] - 430s 7s/step - loss: 0.6449 - accuracy: 0.6776 - val_loss: 1.0288 - val_accuracy: 0.5831
# Epoch 27/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.6106 - accuracy: 0.6897 - val_loss: 1.1087 - val_accuracy: 0.5729
# Epoch 28/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.5859 - accuracy: 0.7143 - val_loss: 1.1136 - val_accuracy: 0.5371
# Epoch 29/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.6303 - accuracy: 0.6984 - val_loss: 1.0834 - val_accuracy: 0.5448
# Epoch 30/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.6229 - accuracy: 0.7050 - val_loss: 1.1782 - val_accuracy: 0.5729
# Epoch 31/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.6059 - accuracy: 0.7148 - val_loss: 1.0535 - val_accuracy: 0.5882
# Epoch 32/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.5782 - accuracy: 0.7252 - val_loss: 1.2744 - val_accuracy: 0.5703
# Epoch 33/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.5752 - accuracy: 0.7263 - val_loss: 1.5409 - val_accuracy: 0.5780
# Epoch 34/200
# 58/58 [==============================] - 2918s 51s/step - loss: 0.5887 - accuracy: 0.7296 - val_loss: 1.2871 - val_accuracy: 0.5882
# Epoch 35/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.5618 - accuracy: 0.7477 - val_loss: 1.1353 - val_accuracy: 0.6113
# Epoch 36/200
# 58/58 [==============================] - 432s 7s/step - loss: 0.5236 - accuracy: 0.7444 - val_loss: 1.2291 - val_accuracy: 0.6113
# Epoch 37/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.5600 - accuracy: 0.7493 - val_loss: 1.0486 - val_accuracy: 0.6164
# Epoch 38/200
# 58/58 [==============================] - 429s 7s/step - loss: 0.5263 - accuracy: 0.7625 - val_loss: 1.0975 - val_accuracy: 0.6215
# Epoch 39/200
# 58/58 [==============================] - 427s 7s/step - loss: 0.5212 - accuracy: 0.7805 - val_loss: 1.2324 - val_accuracy: 0.6215
# Epoch 40/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.5263 - accuracy: 0.7608 - val_loss: 1.2215 - val_accuracy: 0.6189
# Epoch 41/200
# 58/58 [==============================] - 423s 7s/step - loss: 0.4901 - accuracy: 0.7822 - val_loss: 1.1426 - val_accuracy: 0.6189
# Epoch 42/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.4662 - accuracy: 0.7969 - val_loss: 1.2390 - val_accuracy: 0.6496
# Epoch 43/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.5297 - accuracy: 0.7843 - val_loss: 1.2739 - val_accuracy: 0.6496
# Epoch 44/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.4707 - accuracy: 0.8095 - val_loss: 1.3615 - val_accuracy: 0.6496
# Epoch 45/200
# 58/58 [==============================] - 926s 16s/step - loss: 0.4532 - accuracy: 0.8024 - val_loss: 1.2428 - val_accuracy: 0.6292
# Epoch 46/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.5082 - accuracy: 0.8128 - val_loss: 1.1766 - val_accuracy: 0.6292
# Epoch 47/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.5195 - accuracy: 0.7712 - val_loss: 1.5057 - val_accuracy: 0.6471
# Epoch 48/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.5325 - accuracy: 0.8106 - val_loss: 1.4405 - val_accuracy: 0.6777
# Epoch 49/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.4230 - accuracy: 0.8216 - val_loss: 1.1565 - val_accuracy: 0.6701
# Epoch 50/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.4274 - accuracy: 0.8303 - val_loss: 1.3331 - val_accuracy: 0.6701
# Epoch 51/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.4701 - accuracy: 0.8511 - val_loss: 1.4363 - val_accuracy: 0.6419
# Epoch 52/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.3960 - accuracy: 0.8533 - val_loss: 1.3353 - val_accuracy: 0.6957
# Epoch 53/200
# 58/58 [==============================] - 8251s 145s/step - loss: 0.4246 - accuracy: 0.8539 - val_loss: 1.4144 - val_accuracy: 0.7110
# Epoch 54/200
# 58/58 [==============================] - 433s 7s/step - loss: 0.3500 - accuracy: 0.8637 - val_loss: 1.5011 - val_accuracy: 0.6957
# Epoch 55/200
# 58/58 [==============================] - 429s 7s/step - loss: 0.3274 - accuracy: 0.8752 - val_loss: 1.1488 - val_accuracy: 0.6854
# Epoch 56/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.3158 - accuracy: 0.8834 - val_loss: 1.2577 - val_accuracy: 0.7340
# Epoch 57/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.2644 - accuracy: 0.9059 - val_loss: 1.3142 - val_accuracy: 0.7442
# Epoch 58/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.3292 - accuracy: 0.8966 - val_loss: 1.1185 - val_accuracy: 0.7084
# Epoch 59/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.3354 - accuracy: 0.9091 - val_loss: 1.5941 - val_accuracy: 0.7187
# Epoch 60/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.3470 - accuracy: 0.8960 - val_loss: 1.2903 - val_accuracy: 0.6752
# Epoch 61/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.2632 - accuracy: 0.9119 - val_loss: 1.2102 - val_accuracy: 0.6957
# Epoch 62/200
# 58/58 [==============================] - 17227s 302s/step - loss: 0.2809 - accuracy: 0.9135 - val_loss: 1.2448 - val_accuracy: 0.7442
# Epoch 63/200
# 58/58 [==============================] - 420s 7s/step - loss: 0.2660 - accuracy: 0.9338 - val_loss: 1.4217 - val_accuracy: 0.7391
# Epoch 64/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.2572 - accuracy: 0.9294 - val_loss: 1.3540 - val_accuracy: 0.7212
# Epoch 65/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1980 - accuracy: 0.9376 - val_loss: 1.2960 - val_accuracy: 0.7263
# Epoch 66/200
# 58/58 [==============================] - 430s 7s/step - loss: 0.2076 - accuracy: 0.9403 - val_loss: 1.6324 - val_accuracy: 0.7238
# Epoch 67/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.2622 - accuracy: 0.9409 - val_loss: 1.5266 - val_accuracy: 0.7519
# Epoch 68/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.1824 - accuracy: 0.9371 - val_loss: 1.3291 - val_accuracy: 0.7647
# Epoch 69/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1540 - accuracy: 0.9535 - val_loss: 1.3999 - val_accuracy: 0.7596
# Epoch 70/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.2339 - accuracy: 0.9535 - val_loss: 1.7517 - val_accuracy: 0.7110
# Epoch 71/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.2074 - accuracy: 0.9431 - val_loss: 1.5543 - val_accuracy: 0.7442
# Epoch 72/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1953 - accuracy: 0.9480 - val_loss: 1.8109 - val_accuracy: 0.7033
# Epoch 73/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1970 - accuracy: 0.9524 - val_loss: 1.5056 - val_accuracy: 0.7621
# Epoch 74/200
# 58/58 [==============================] - 2255s 39s/step - loss: 0.2232 - accuracy: 0.9502 - val_loss: 2.4819 - val_accuracy: 0.7366
# Epoch 75/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.1740 - accuracy: 0.9579 - val_loss: 1.9644 - val_accuracy: 0.7289
# Epoch 76/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1554 - accuracy: 0.9628 - val_loss: 1.8579 - val_accuracy: 0.7187
# Epoch 77/200
# 58/58 [==============================] - 427s 7s/step - loss: 0.1461 - accuracy: 0.9557 - val_loss: 1.9565 - val_accuracy: 0.7417
# Epoch 78/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1648 - accuracy: 0.9650 - val_loss: 2.2953 - val_accuracy: 0.7570
# Epoch 79/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1807 - accuracy: 0.9622 - val_loss: 2.2391 - val_accuracy: 0.7366
# Epoch 80/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1345 - accuracy: 0.9666 - val_loss: 2.8210 - val_accuracy: 0.7263
# Epoch 81/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.1340 - accuracy: 0.9655 - val_loss: 2.5349 - val_accuracy: 0.7647
# Epoch 82/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.1371 - accuracy: 0.9672 - val_loss: 2.5766 - val_accuracy: 0.7494
# Epoch 83/200
# 58/58 [==============================] - 21476s 377s/step - loss: 0.0825 - accuracy: 0.9803 - val_loss: 2.2991 - val_accuracy: 0.7468
# Epoch 84/200
# 58/58 [==============================] - 423s 7s/step - loss: 0.1521 - accuracy: 0.9639 - val_loss: 2.1180 - val_accuracy: 0.7442
# Epoch 85/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1479 - accuracy: 0.9737 - val_loss: 2.5089 - val_accuracy: 0.7596
# Epoch 86/200
# 58/58 [==============================] - 429s 7s/step - loss: 0.0938 - accuracy: 0.9787 - val_loss: 2.5100 - val_accuracy: 0.7519
# Epoch 87/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.0946 - accuracy: 0.9759 - val_loss: 2.6790 - val_accuracy: 0.7519
# Epoch 88/200
# 58/58 [==============================] - 436s 8s/step - loss: 0.1031 - accuracy: 0.9743 - val_loss: 2.9251 - val_accuracy: 0.7570
# Epoch 89/200
# 58/58 [==============================] - 433s 7s/step - loss: 0.1498 - accuracy: 0.9759 - val_loss: 2.7276 - val_accuracy: 0.7442
# Epoch 90/200
# 58/58 [==============================] - 428s 7s/step - loss: 0.1551 - accuracy: 0.9677 - val_loss: 2.9528 - val_accuracy: 0.7391
# Epoch 91/200
# 58/58 [==============================] - 427s 7s/step - loss: 0.1324 - accuracy: 0.9748 - val_loss: 2.5365 - val_accuracy: 0.7698
# Epoch 92/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.1082 - accuracy: 0.9743 - val_loss: 3.1414 - val_accuracy: 0.7238
# Epoch 93/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1492 - accuracy: 0.9754 - val_loss: 3.2010 - val_accuracy: 0.7442
# Epoch 94/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.1504 - accuracy: 0.9759 - val_loss: 2.7969 - val_accuracy: 0.7366
# Epoch 95/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.0892 - accuracy: 0.9770 - val_loss: 2.9670 - val_accuracy: 0.7468
# Epoch 96/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.1639 - accuracy: 0.9814 - val_loss: 3.0224 - val_accuracy: 0.7468
# Epoch 97/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.1589 - accuracy: 0.9704 - val_loss: 2.1819 - val_accuracy: 0.7417
# Epoch 98/200
# 58/58 [==============================] - 6240s 109s/step - loss: 0.0624 - accuracy: 0.9819 - val_loss: 2.7341 - val_accuracy: 0.7263
# Epoch 99/200
# 58/58 [==============================] - 433s 7s/step - loss: 0.1388 - accuracy: 0.9776 - val_loss: 3.4483 - val_accuracy: 0.7545
# Epoch 100/200
# 58/58 [==============================] - 432s 7s/step - loss: 0.0855 - accuracy: 0.9814 - val_loss: 2.7725 - val_accuracy: 0.7647
# Epoch 101/200
# 58/58 [==============================] - 432s 7s/step - loss: 0.0900 - accuracy: 0.9852 - val_loss: 2.9851 - val_accuracy: 0.7494
# Epoch 102/200
# 58/58 [==============================] - 429s 7s/step - loss: 0.0925 - accuracy: 0.9841 - val_loss: 2.5175 - val_accuracy: 0.7877
# Epoch 103/200
# 58/58 [==============================] - 430s 7s/step - loss: 0.0552 - accuracy: 0.9852 - val_loss: 2.9011 - val_accuracy: 0.7621
# Epoch 104/200
# 58/58 [==============================] - 433s 7s/step - loss: 0.0988 - accuracy: 0.9847 - val_loss: 2.9827 - val_accuracy: 0.7417
# Epoch 105/200
# 58/58 [==============================] - 433s 7s/step - loss: 0.1014 - accuracy: 0.9819 - val_loss: 2.8355 - val_accuracy: 0.7238
# Epoch 106/200
# 58/58 [==============================] - 431s 7s/step - loss: 0.0660 - accuracy: 0.9847 - val_loss: 2.6075 - val_accuracy: 0.7545
# Epoch 107/200
# 58/58 [==============================] - 433s 7s/step - loss: 0.0360 - accuracy: 0.9951 - val_loss: 2.9752 - val_accuracy: 0.7749
# Epoch 108/200
# 58/58 [==============================] - 431s 7s/step - loss: 0.0410 - accuracy: 0.9951 - val_loss: 3.3573 - val_accuracy: 0.7903
# Epoch 109/200
# 58/58 [==============================] - 432s 7s/step - loss: 0.0450 - accuracy: 0.9869 - val_loss: 3.1059 - val_accuracy: 0.7826
# Epoch 110/200
# 58/58 [==============================] - 431s 7s/step - loss: 0.0314 - accuracy: 0.9929 - val_loss: 2.9931 - val_accuracy: 0.8005
# Epoch 111/200
# 58/58 [==============================] - 430s 7s/step - loss: 0.0348 - accuracy: 0.9918 - val_loss: 3.5372 - val_accuracy: 0.7826
# Epoch 112/200
# 58/58 [==============================] - 430s 7s/step - loss: 0.0681 - accuracy: 0.9891 - val_loss: 3.0138 - val_accuracy: 0.7801
# Epoch 113/200
# 58/58 [==============================] - 432s 7s/step - loss: 0.0511 - accuracy: 0.9896 - val_loss: 2.9820 - val_accuracy: 0.7801
# Epoch 114/200
# 58/58 [==============================] - 434s 7s/step - loss: 0.3179 - accuracy: 0.9513 - val_loss: 3.4217 - val_accuracy: 0.7366
# Epoch 115/200
# 58/58 [==============================] - 434s 7s/step - loss: 0.1198 - accuracy: 0.9803 - val_loss: 2.6152 - val_accuracy: 0.7724
# Epoch 116/200
# 58/58 [==============================] - 449s 8s/step - loss: 0.0655 - accuracy: 0.9852 - val_loss: 3.3424 - val_accuracy: 0.7775
# Epoch 117/200
# 58/58 [==============================] - 453s 8s/step - loss: 0.1154 - accuracy: 0.9841 - val_loss: 3.4292 - val_accuracy: 0.7724
# Epoch 118/200
# 58/58 [==============================] - 446s 8s/step - loss: 0.0669 - accuracy: 0.9852 - val_loss: 3.7850 - val_accuracy: 0.7826
# Epoch 119/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.0865 - accuracy: 0.9814 - val_loss: 3.6191 - val_accuracy: 0.7494
# Epoch 120/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.0477 - accuracy: 0.9891 - val_loss: 3.5064 - val_accuracy: 0.7775
# Epoch 121/200
# 58/58 [==============================] - 426s 7s/step - loss: 0.1117 - accuracy: 0.9825 - val_loss: 3.2158 - val_accuracy: 0.7801
# Epoch 122/200
# 58/58 [==============================] - 427s 7s/step - loss: 0.0521 - accuracy: 0.9885 - val_loss: 3.1158 - val_accuracy: 0.7647
# Epoch 123/200
# 58/58 [==============================] - 424s 7s/step - loss: 0.0675 - accuracy: 0.9847 - val_loss: 3.4195 - val_accuracy: 0.7647
# Epoch 124/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.0276 - accuracy: 0.9901 - val_loss: 3.1933 - val_accuracy: 0.7801
# Epoch 125/200
# 58/58 [==============================] - 18000s 316s/step - loss: 0.0403 - accuracy: 0.9918 - val_loss: 2.5002 - val_accuracy: 0.7954
# Epoch 126/200
# 58/58 [==============================] - 442s 8s/step - loss: 0.0350 - accuracy: 0.9918 - val_loss: 2.8930 - val_accuracy: 0.7826
# Epoch 127/200
# 58/58 [==============================] - 436s 8s/step - loss: 0.0314 - accuracy: 0.9945 - val_loss: 3.3128 - val_accuracy: 0.7647
# Epoch 128/200
# 58/58 [==============================] - 435s 8s/step - loss: 0.0282 - accuracy: 0.9951 - val_loss: 3.6233 - val_accuracy: 0.7877
# Epoch 129/200
# 58/58 [==============================] - 435s 8s/step - loss: 0.0287 - accuracy: 0.9951 - val_loss: 2.9792 - val_accuracy: 0.7852
# Epoch 130/200
# 58/58 [==============================] - 435s 8s/step - loss: 0.0575 - accuracy: 0.9918 - val_loss: 3.3710 - val_accuracy: 0.7852
# Epoch 131/200
# 58/58 [==============================] - 431s 7s/step - loss: 0.1455 - accuracy: 0.9825 - val_loss: 3.8089 - val_accuracy: 0.7826
# Epoch 132/200
# 58/58 [==============================] - 433s 7s/step - loss: 0.2311 - accuracy: 0.9770 - val_loss: 4.0799 - val_accuracy: 0.7801
# Epoch 133/200
# 58/58 [==============================] - 435s 7s/step - loss: 0.0546 - accuracy: 0.9901 - val_loss: 3.6229 - val_accuracy: 0.7980
# Epoch 134/200
# 58/58 [==============================] - 9061s 159s/step - loss: 0.1630 - accuracy: 0.9803 - val_loss: 2.8177 - val_accuracy: 0.7724
# Epoch 135/200
# 58/58 [==============================] - 900s 16s/step - loss: 0.0933 - accuracy: 0.9907 - val_loss: 3.1989 - val_accuracy: 0.7801
# Epoch 136/200
# 58/58 [==============================] - 902s 16s/step - loss: 0.0580 - accuracy: 0.9901 - val_loss: 3.3798 - val_accuracy: 0.8005
# Epoch 137/200
# 58/58 [==============================] - 909s 16s/step - loss: 0.0643 - accuracy: 0.9912 - val_loss: 3.1792 - val_accuracy: 0.8005
# Epoch 138/200
# 58/58 [==============================] - 10973s 192s/step - loss: 0.0734 - accuracy: 0.9901 - val_loss: 3.2442 - val_accuracy: 0.8005
# Epoch 139/200
# 58/58 [==============================] - 911s 16s/step - loss: 0.2145 - accuracy: 0.9814 - val_loss: 3.0644 - val_accuracy: 0.7698
# Epoch 140/200
# 58/58 [==============================] - 905s 16s/step - loss: 0.1830 - accuracy: 0.9852 - val_loss: 2.8142 - val_accuracy: 0.8031
# Epoch 141/200
# 58/58 [==============================] - 904s 16s/step - loss: 0.0830 - accuracy: 0.9863 - val_loss: 3.4804 - val_accuracy: 0.7724
# Epoch 142/200
# 58/58 [==============================] - 10247s 180s/step - loss: 0.0305 - accuracy: 0.9934 - val_loss: 2.5164 - val_accuracy: 0.7903
# Epoch 143/200
# 58/58 [==============================] - 903s 16s/step - loss: 0.0331 - accuracy: 0.9962 - val_loss: 3.0701 - val_accuracy: 0.7928
# Epoch 144/200
# 58/58 [==============================] - 906s 16s/step - loss: 0.0259 - accuracy: 0.9956 - val_loss: 3.3118 - val_accuracy: 0.8133
# Epoch 145/200
# 58/58 [==============================] - 901s 16s/step - loss: 0.0346 - accuracy: 0.9951 - val_loss: 3.2308 - val_accuracy: 0.7801
# Epoch 146/200
# 58/58 [==============================] - 830s 14s/step - loss: 0.0469 - accuracy: 0.9956 - val_loss: 2.4375 - val_accuracy: 0.7928
# Epoch 147/200
# 58/58 [==============================] - 471s 8s/step - loss: 0.0169 - accuracy: 0.9962 - val_loss: 3.2221 - val_accuracy: 0.7877
# Epoch 148/200
# 58/58 [==============================] - 607s 11s/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 3.1279 - val_accuracy: 0.7775
# Epoch 149/200
# 58/58 [==============================] - 826s 14s/step - loss: 0.0051 - accuracy: 0.9978 - val_loss: 2.9018 - val_accuracy: 0.7877
# Epoch 150/200
# 58/58 [==============================] - 826s 14s/step - loss: 0.0155 - accuracy: 0.9973 - val_loss: 2.7725 - val_accuracy: 0.7852
# Epoch 151/200
# 58/58 [==============================] - 836s 14s/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 2.6121 - val_accuracy: 0.8005
# Epoch 152/200
# 58/58 [==============================] - 836s 14s/step - loss: 0.0432 - accuracy: 0.9945 - val_loss: 3.5957 - val_accuracy: 0.7826
# Epoch 153/200
# 58/58 [==============================] - 45523s 798s/step - loss: 0.0354 - accuracy: 0.9956 - val_loss: 3.2950 - val_accuracy: 0.7928
# Epoch 154/200
# 58/58 [==============================] - 835s 14s/step - loss: 0.0672 - accuracy: 0.9956 - val_loss: 3.7919 - val_accuracy: 0.7698
# Epoch 155/200
# 58/58 [==============================] - 829s 14s/step - loss: 0.0108 - accuracy: 0.9978 - val_loss: 3.2267 - val_accuracy: 0.7826
# Epoch 156/200
# 58/58 [==============================] - 827s 14s/step - loss: 0.0309 - accuracy: 0.9945 - val_loss: 3.2890 - val_accuracy: 0.7877
# Epoch 157/200
# 58/58 [==============================] - 4805s 84s/step - loss: 0.0214 - accuracy: 0.9978 - val_loss: 3.5270 - val_accuracy: 0.7621
# Epoch 158/200
# 58/58 [==============================] - 842s 15s/step - loss: 0.0562 - accuracy: 0.9934 - val_loss: 2.5286 - val_accuracy: 0.7775
# Epoch 159/200
# 58/58 [==============================] - 828s 14s/step - loss: 0.0181 - accuracy: 0.9956 - val_loss: 2.6587 - val_accuracy: 0.7775
# Epoch 160/200
# 58/58 [==============================] - 834s 14s/step - loss: 0.0243 - accuracy: 0.9951 - val_loss: 4.9645 - val_accuracy: 0.7724
# Epoch 161/200
# 58/58 [==============================] - 831s 14s/step - loss: 0.2142 - accuracy: 0.9808 - val_loss: 2.5088 - val_accuracy: 0.7775
# Epoch 162/200
# 58/58 [==============================] - 25353s 445s/step - loss: 0.1323 - accuracy: 0.9781 - val_loss: 2.8473 - val_accuracy: 0.7673
# Epoch 163/200
# 58/58 [==============================] - 842s 14s/step - loss: 0.6432 - accuracy: 0.9469 - val_loss: 4.0851 - val_accuracy: 0.7340
# Epoch 164/200
# 58/58 [==============================] - 837s 14s/step - loss: 0.1180 - accuracy: 0.9863 - val_loss: 3.6508 - val_accuracy: 0.7724
# Epoch 165/200
# 58/58 [==============================] - 829s 14s/step - loss: 0.1486 - accuracy: 0.9869 - val_loss: 3.6976 - val_accuracy: 0.7980
# Epoch 166/200
# 58/58 [==============================] - 831s 14s/step - loss: 0.1683 - accuracy: 0.9814 - val_loss: 4.0688 - val_accuracy: 0.7673
# Epoch 167/200
# 58/58 [==============================] - 832s 14s/step - loss: 0.1906 - accuracy: 0.9869 - val_loss: 4.0154 - val_accuracy: 0.7852
# Epoch 168/200
# 58/58 [==============================] - 2540s 44s/step - loss: 0.1360 - accuracy: 0.9901 - val_loss: 3.1620 - val_accuracy: 0.7826
# Epoch 169/200
# 58/58 [==============================] - 831s 14s/step - loss: 0.1618 - accuracy: 0.9841 - val_loss: 4.3090 - val_accuracy: 0.7980
# Epoch 170/200
# 58/58 [==============================] - 832s 14s/step - loss: 0.2725 - accuracy: 0.9814 - val_loss: 3.8987 - val_accuracy: 0.7673
# Epoch 171/200
# 58/58 [==============================] - 835s 14s/step - loss: 0.1460 - accuracy: 0.9836 - val_loss: 4.6224 - val_accuracy: 0.7775
# Epoch 172/200
# 58/58 [==============================] - 1728s 30s/step - loss: 0.1045 - accuracy: 0.9923 - val_loss: 3.4398 - val_accuracy: 0.7954
# Epoch 173/200
# 58/58 [==============================] - 425s 7s/step - loss: 0.0405 - accuracy: 0.9929 - val_loss: 3.9251 - val_accuracy: 0.8107
# Epoch 174/200
# 58/58 [==============================] - 432s 7s/step - loss: 0.0586 - accuracy: 0.9945 - val_loss: 3.5197 - val_accuracy: 0.7980
# 13/13 [==============================] - 19s 1s/step - loss: 3.3118 - accuracy: 0.8133
# Validation Loss: 3.311762571334839
# Validation Accuracy: 0.8132992386817932
# 13/13 [==============================] - 20s 1s/step - loss: 2.8550 - accuracy: 0.8469
# Test Loss: 2.8549716472625732
# Test Accuracy: 0.8469387888908386

# %%
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=1)
df = pd.DataFrame(data = confusion_matrix(y_test, predictions),
  columns = ['CN','MCI', 'AD'],
  index = ['CN','MCI', 'AD'])
sns.heatmap(df, cmap="Greens", annot=True, fmt='.0f')
# Out:
# 13/13 [==============================] - 19s 1s/step
# <Axes: >

# %%
mat = confusion_matrix(y_test, predictions)
df =pd.DataFrame((mat/mat.sum(axis = 1,keepdims = True)).round(2), columns = ['CN','MCI', 'AD'],index = ['CN','MCI', 'AD'])
sns.heatmap(df, cmap="Greens", annot=True)
# Out:
# <Axes: >

# %%
predictions = model.predict(x_val)
predictions = np.argmax(predictions, axis=1)
df = pd.DataFrame(data = confusion_matrix(y_val, predictions),
  columns = ['CN','MCI', 'AD'],
  index = ['CN','MCI', 'AD'])
sns.heatmap(df, cmap="Greens", annot=True, fmt='.0f')
# Out:
# 13/13 [==============================] - 21s 2s/step
# <Axes: >

# %%
mat = confusion_matrix(y_val, predictions)
df =pd.DataFrame((mat/mat.sum(axis = 1,keepdims = True)).round(2), columns = ['CN','MCI', 'AD'],index = ['CN','MCI', 'AD'])
sns.heatmap(df, cmap="Greens", annot=True)
# Out:
# <Axes: >

# %%
epochs_applied = early_stopping.stopped_epoch + 1
if epochs_applied<10:
    epochs_applied=200

# %%
lenx = [i+1 for i in range(epochs_applied)]
plt.plot(lenx, train_acc_values, label = "train acc")
plt.plot(lenx, val_acc_values, label = "val acc")
plt.legend()
plt.show()

# %%
lenx = [i+1 for i in range(epochs_applied-1)]
plt.plot(lenx, train_loss_values[1:],label = "train loss")
plt.plot(lenx, val_loss_values[1:], label = "val loss")
#plt.plot(lenx, test_loss_values, label = "test loss")
plt.legend()
plt.show()
